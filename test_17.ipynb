# %% [markdown]
# # 17. 3진법뒤집기
#
# 자연수 n이 매개변수로 주어집니다. n을 3진법 상에서 앞뒤로 뒤집은 후, 이를 다시 10진법으로 표현한 수를 return 하도록 solution 함수를 완성해주세요.
#
# n은 1 이상 100,000,000 이하인 자연수입니다.
#
# n	result
#
# 45	7
#
# 125	229
#
#
# - n (10진법) n(3진법) 앞뒤 반전(3진법)	10진법으로 표현
# - [45, 1200, 0021, 7]
# - 따라서 7을 return 해야 합니다.

# %%
def solution(n):
    answer = 0
    n_list = []
    if n < 3:
        n_list = [n%3]
    
    else:
        for i in range(17):
            n_list.append(n%3)
            n = n//3
        
            if n < 3:
                n_list.append(n%3)
                break
    
    for i,v in enumerate(n_list):
        answer += v*(3**(len(n_list)-1-i))
    return answer

# %%
n = 125
solution(n)
# Out:
# [2, 2, 1, 1, 1]
# 229

# %%
def solution(n):
    tmp = ''
    while n:

        tmp += str(n % 3)
        n = n // 3

    answer = int(tmp, 3)
    return answer

# %%
n=125
solution(n)
# Out:
# 229

# %% [markdown]
# ### while 0: 는 while False 와 같은 기능

# %%
while 0:
    print('no')
while False:
    print('yes')
