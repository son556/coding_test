# %%
# 8
길이가 같은 두 1차원 정수 배열 a, b가
매개변수로 주어집니다. a와 b의 내적을 
return 하도록 solution 함수를 완성해주세요.

이때, a와 b의 내적은 
a[0]*b[0] + a[1]*b[1] + ... + a[n-1]*b[n-1] 입니다. (n은 a, b의 길이)
[1,2,3,4]	[-3,-1,0,2]	3
[-1,0,1]	[1,0,-1]	-2

# %%
def solution(a,b):
    answer = 0
    for i in range(len(a)):
        answer += a[i]*b[i]
    
    return answer

# %%
a = [-1,0,1]ㅠ
b = [1,0,-1]
solution(a,b)
# Out:
# -2

# %%
def solution(a, b):

    return sum([x*y for x, y in zip(a,b)])

# %%
a = [-2,0,1]
b = [1,0,-1]

for i,j in zip(a,b):
    x += i+j
print(x)
# Out:
# -1

# %%
# 9
문제 설명
주어진 숫자 중 3개의 수를 더했을 때 
소수가 되는 경우의 개수를 구하려고 합니다. 
숫자들이 들어있는 배열 nums가 매개변수로 주어질 때, 
nums에 있는 숫자들 중 서로 다른 3개를 골라 더했을 때 
소수가 되는 경우의 개수를 return 하도록 solution 함수를 완성해주세요.

제한사항
nums에 들어있는 숫자의 개수는 3개 이상 50개 이하입니다.
nums의 각 원소는 1 이상 1,000 이하의 자연수이며, 
중복된 숫자가 들어있지 않습니다.

[1,2,3,4]	1
[1,2,7,6,4]	4

# %%
import itertools
def solution(nums):
    count = 0
    result = list(itertools.combinations(nums,3))
    num = []
    for i in result:
        num.append(i[0]+i[1]+i[2])

    for j in range(len(num)):
        for i in range(2,num[j]):
            if num[j]%i == 0:
                break
            elif i == num[j]-1:
                count += 1
            
    answer = count
    return answer

# %%
nums = [1,2,7,6,4]
solution(nums)
# Out:
# 4

# %%
import itertools 
result = list(itertools.combinations((["1","2","3","4"]),3))
result
# Out:
# [('1', '2', '3'), ('1', '2', '4'), ('1', '3', '4'), ('2', '3', '4')]

# %%
num = 15
for i in range(2,num):
    if num%i == 0:
        print('소수아님')
        break
    elif i == num-1:
        print('소수')
# Out:
# 소수아님

# %%
# import random
# random.sample #중복x 뽑기
# random.choice #중복o 뽑기

# %%
import random
j_list = (1,2,3,4,5)
for i in range(10):
    print(random.sample(j_list,2))
# Out:
# [5, 2]
# [3, 4]
# [5, 2]
# [2, 1]
# [4, 1]
# [3, 1]
# [1, 3]
# [3, 2]
# [4, 5]
# [5, 2]
