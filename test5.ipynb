# %%
board 배열은 2차원 배열로 크기는 "5 x 5" 이상 "30 x 30" 이하입니다.
board의 각 칸에는 0 이상 100 이하인 정수가 담겨있습니다.
0은 빈 칸을 나타냅니다.
1 ~ 100의 각 숫자는 각기 다른 인형의 모양을 의미하며 
같은 숫자는 같은 모양의 인형을 나타냅니다.
moves 배열의 크기는 1 이상 1000 이하입니다.
moves 배열 각 원소들의 값은 1 이상이며 board 배열의 가로 크기 
이하인 자연수입니다.
입출력 예
board	moves	result
board : [[0,0,0,0,0],[0,0,1,0,3],[0,2,5,0,1],[4,2,4,4,2],[3,5,1,3,1]]
moves : [1,5,3,5,1,2,1,4]	4

# %%
def solution(board, moves):
    answer = 0
    result_list = []
    count = 0
    for j in moves:# 뽑기
        for i in range(len(board)):
            if board[i][j-1] == 0:
                continue
            else:
                if len(result_list) > 0:
                    if result_list[-1] == board[i][j-1]:
                        del result_list[-1]
                        count += 1
                        board[i][j-1] = 0
                        break
                    else:
                        result_list.append(board[i][j-1])
                        board[i][j-1] = 0
                        break
                else:
                    result_list.append(board[i][j-1])
                    board[i][j-1] = 0
                    break
    answer = count*2
    return answer,result_list

# %%
board = [[0,0,0,0,0],[0,0,1,0,3],[0,2,5,0,1],[4,2,4,4,2],[3,5,1,3,1]]
moves = [1,5,3,5,1,2,1,4]
solution(board,moves)
# Out:
# (4, [4, 2, 4])

# %%
import numpy as np
import pandas as pd
r = pd.DataFrame({'a':[1,2,3],'b':[1,2,4]})
c = pd.DataFrame({'c':[5,5,5],'d':[0,0,0]})
print(r)
c.c + r.a
# Out:
#    a  b
# 0  1  1
# 1  2  2
# 2  3  4
# 0    6
# 1    7
# 2    8
# dtype: int64

# %%
# 뽑기, 확인
for j in moves:
    for i in range(len(board)):
        if board[i][j-1] == 0:
            continue
        else:
            result_list.append(board[i][j-1])
# 같은거 없애기, 없앤 요소 수 count
r_list = result_list
k = len(result_list)
for i,x in enumerate(result_list):
    if i>0:
        if result_list[i] == result_list[i-1]:
            del result_list[i]
            del result_list[i-1]
        else:
            continue

print('r_list:',r_list)
print()
print('result_list',result_list)
print(count)
# Out:
# [4, 3, 3, 1, 2, 1, 1, 5, 4, 1, 3, 1, 2, 1, 4, 3, 2, 2, 5, 4, 3, 4, 3]
# 23
# r_list: [4, 1, 2, 5, 4, 1, 3, 1, 2, 1, 4, 3, 5, 4, 3, 4, 3]
#
# result_list [4, 1, 2, 5, 4, 1, 3, 1, 2, 1, 4, 3, 5, 4, 3, 4, 3]
# 3

# %%
result_list = [4, 3, 3, 1, 2, 1, 1, 1, 4, 3, 4, 3]
k = len(result_list)
for i,x in enumerate(result_list):
    if i>0:
        if result_list[i] == result_list[i-1]:
            del result_list[i]
            del result_list[i-1]
        else:
            continue

print('r_list:',r_list)
print()
print('result_list',result_list)
print(k - len(r_list))
# Out:
# r_list: [4, 1, 2, 1, 4, 3, 4, 3]
#
# result_list [4, 1, 2, 1, 4, 3, 4, 3]
# 4

# %%
moves = [1,5,3,5,1,2,1,4]
max(moves)
# Out:
# 5
