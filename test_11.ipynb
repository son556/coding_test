# %%
# 11
배열 array의 i번째 숫자부터 j번째 숫자까지 자르고 정렬했을 때, 
k번째에 있는 수를 구하려 합니다.

예를 들어 array가 [1, 5, 2, 6, 3, 7, 4], i = 2, j = 5, k = 3이라면

array의 2번째부터 5번째까지 자르면 [5, 2, 6, 3]입니다.
1에서 나온 배열을 정렬하면 [2, 3, 5, 6]입니다.
2에서 나온 배열의 3번째 숫자는 5입니다.
배열 array, [i, j, k]를 원소로 가진 2차원 배열 commands가 매개변수로 주어질 때
, commands의 모든 원소에 대해 앞서 설명한 연산을 적용했을 때 
나온 결과를 배열에 담아 return 하도록 solution 함수를 작성해주세요.

제한사항
array의 길이는 1 이상 100 이하입니다.
array의 각 원소는 1 이상 100 이하입니다.
commands의 길이는 1 이상 50 이하입니다.
commands의 각 원소는 길이가 3입니다.
입출력 예
array	commands	return
[1, 5, 2, 6, 3, 7, 4]	[[2, 5, 3], [4, 4, 1], [1, 7, 3]]	[5, 6, 3]

# %%
# my solution
def solution(array, commands):
    answer = []
    for i in commands:
        x = array[i[0]-1:i[1]]
        x.sort()
        answer.append(x[i[2]-1])
        
    return answer

# %%
array = [1, 5, 2, 6, 3, 7, 4]
commands = [[2, 5, 3], [4, 4, 1], [1, 7, 3]]
solution(array, commands)
# Out:
# [5, 6, 3]

# %%
answer =[]
commands = [[2, 5, 3], [4, 4, 1], [1, 7, 3]]
array = [1, 5, 2, 6, 3, 7, 4]
len(commands)
for command in commands:
        i,j,k = command
        answer.append(list(sorted(array[i-1:j]))[k-1])
print(answer)
# i,j,k = command 로 한번에 입력가능
# Out:
# [5, 6, 3]

# %%
# lambda 함수 이용, 규칙

# lambda 매개변수 : 표현식

(lambda x,y: x + y)(10, 20)

# map(함수, 리스트)

print(map(lambda x: x ** 2, range(5)))

print(list(map(lambda x: x ** 2, range(5))))
# Out:
# ...
# [0, 1, 4, 9, 16]

# %% [markdown]
# ###### Python lambda 함수는 튜플 매개 변수를 두 개의 인수로 압축 해제 할 수 없습니다 :

# %%
print((lambda x, y: y + x,range(4)))
# Out:
# (<function <lambda> at 0x000001DD50472670>, range(0, 4))

# %%
list(map(lambda x: x ** 2, range(5)))
# Out:
# [0, 1, 4, 9, 16]

# %%
from functools import reduce
reduce(lambda x, y: y + x, 'abcde')
reduce(lambda x, y: x + y, [0, 1, 2, 3, 4])
# Out:
# 10

# %%
list(range(4))
# Out:
# [0, 1, 2, 3]

# %%
a = ('a','b','c')
b = ('c','d','e')
a+b
# Out:
# ('a', 'b', 'c', 'c', 'd', 'e')
